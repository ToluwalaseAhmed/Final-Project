# %% [markdown]
# ## <center> Water Fountains in Pittsburgh Neighborhoods </center>

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

water_fountain_data = pd.read_csv("water-fountain-data.csv")

# %%
water_fountain_data.head(10) # Looking at the first 10 rows of the data
# Out:
#            id                                  name control_type  \
# 0  1816791851                        Able Long Park   Continuous
# 1  1599892422               Albert Turk Graham Park       On/Off
# 2  1422043278             Allegheny Commons Arch St   Continuous
# 3  1237191582  Allegheny Commons East Tennis Courts   Continuous
# 4  1146184773                Allegheny Commons Pool   Continuous
# 5  1230448600                            Alton Park   Continuous
# 6   887743707                   Ammon Park Building       On/Off
# 7  1767127832                      Ammon Park Spray          NaN
# 8   354464900                        Armstrong Park       On/Off
# 9   495479912                  Armstrong Park Spray   Continuous
#
#         feature_type inactive              make  \
# 0  Drinking Fountain        f  Regular Fountain
# 1  Drinking Fountain        f   Most Dependable
# 2  Drinking Fountain        f  Regular Fountain
# 3  Drinking Fountain        f  Regular Fountain
# ...

# %% [markdown]
# By looking at the first 10 rows of the data, we can see that there are different types of water fountains, as indicated by the "feature_type" column. For this assignment, we are specifically looking at the type "Drinking Fountain", so we will remove every other type from the data.

# %%
drinking_fountain_mask = water_fountain_data["feature_type"] == "Drinking Fountain" # Creating a query mask to only display fountains that are considered to be a "Drinking Fountain"
data_adjustment_one = water_fountain_data[drinking_fountain_mask] 
data_adjustment_one.head(10) # Displaying the first ten rows of "Drinking Fountains"
# Out:
#             id                                  name control_type  \
# 0   1816791851                        Able Long Park   Continuous
# 1   1599892422               Albert Turk Graham Park       On/Off
# 2   1422043278             Allegheny Commons Arch St   Continuous
# 3   1237191582  Allegheny Commons East Tennis Courts   Continuous
# 4   1146184773                Allegheny Commons Pool   Continuous
# 5   1230448600                            Alton Park   Continuous
# 6    887743707                   Ammon Park Building       On/Off
# 8    354464900                        Armstrong Park       On/Off
# 10  1616218742                    August Wilson Park       On/Off
# 11   778611148                       Banksville Park   Continuous
#
#          feature_type inactive              make  \
# 0   Drinking Fountain        f  Regular Fountain
# 1   Drinking Fountain        f   Most Dependable
# 2   Drinking Fountain        f  Regular Fountain
# ...

# %% [markdown]
# We have now removed every single row of data that doesn't have the feature type as "drinking fountain". When looking at the .csv file, we see that there is a column named "inactive", where the value is either "false" or the slot is left blank. What good is a water fountain if it isn't active? We now have to remove the rows that have the field blank.

# %%
inactive_mask = data_adjustment_one["inactive"] == "f"
data_adjustment_two = data_adjustment_one[final_mask]
data_adjustment_two
# Out:
#              id                                  name control_type  \
# 0    1816791851                        Able Long Park   Continuous
# 1    1599892422               Albert Turk Graham Park       On/Off
# 2    1422043278             Allegheny Commons Arch St   Continuous
# 3    1237191582  Allegheny Commons East Tennis Courts   Continuous
# 4    1146184773                Allegheny Commons Pool   Continuous
# ..          ...                                   ...          ...
# 180  1588021595                       Westwood Pool 2   Continuous
# 181   670382875                         Wightman Park   Continuous
# 182  1535919927                        Woods Run Park       On/Off
# 183  1125324305                  Mellon Square Park 1       On/Off
# 184    40077078                  Mellon Square Park 2       On/Off
#
#           feature_type inactive              make  \
# 0    Drinking Fountain        f  Regular Fountain
# 1    Drinking Fountain        f   Most Dependable
# ...

# %% [markdown]
# Now our data is ready to be visualized. We have removed all of the inactive water fountains and all the remaining rows now represent active "drinking fountains" that are present in Pittsburgh neighborhoods. But first, we will check how many occurances of active drinking fountains have occurred in each of the neighborhoods.

# %%
data_adjustment_two['neighborhood'].value_counts()
# Out:
# Squirrel Hill South    13
# Highland Park          10
# Perry North             7
# Brookline               7
# Elliott                 6
#                        ..
# Bluff                   1
# Windgap                 1
# South Side Slopes       1
# West End                1
# East Hills              1
# Name: neighborhood, Length: 61, dtype: int64

# %% [markdown]
# With this data, we will create a bar graph with each of the neighborhoods and visualize the differences between each location.

# %%
data_adjustment_two['neighborhood'].value_counts().plot(kind = 'bar')
plt.title("Drinking Fountains in Each Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Occurrences")
plt.figure(figsize =(1,1))

#Ask how to rotate the graph and increase the size of the plotted graph

# %% [markdown]
# From the looks of this graph, it is very cluttered and messy. Lets focus on the neighborhoods that have 3 or more occurances of active drinking fountains in the area.

# %%
occurrences_mask = data_adjustment_two['neighborhood'].value_counts('neighborhood' = )
# Out:
#   File "<ipython-input-45-2a8c25912e75>", line 1
#     occurrences_mask = data_adjustment_two['neighborhood'].value_counts(3 <=)
#                                                                             ^
# SyntaxError: invalid syntax
